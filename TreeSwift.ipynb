# %% [markdown]
# # Reproducing Research Paper Results: TreeSwift
#
# > Moshiri N (2020). "TreeSwift: a massively scalable Python package for trees." *SoftwareX*. 11:100436. [doi:10.1016/j.softx.2020.100436](https://doi.org/10.1016/j.softx.2020.100436)

# %% [markdown]
# # Setting Up the Environment
#
# Before we can run any analyses, we need to first install the packages we are benchmarking.
#
# | Tool        | Version                                             |
# | :---------: | :-----------------------------------------------:   |
# | TreeSwift   | [1.1.45](https://pypi.org/project/treeswift/1.1.45) |
# | Biopython   | [1.85](https://pypi.org/project/biopython/1.85)     |
# | DendroPy    | [4.4.0](https://pypi.org/project/DendroPy/4.4.0)    |
# | ETE Toolkit | [3.1.1](https://pypi.org/project/ete3/3.1.1)        |
# | NetworkX    | [3.4.2](https://pypi.org/project/networkx/3.4.2)    |

# %%
# install tree packages using pip
# !pip install -q treeswift==1.1.45
# !pip install -q biopython==1.85
# !pip install -q dendropy==4.4.0
# !pip install -q ete3==3.1.1
# !pip install -q networkx==3.4.2
# Out:
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Downloading the Data and Code

# %%
# !git clone https://github.com/BrandonWerbel/TreeSwift.git
# Out:
# Cloning into 'TreeSwift'...
# remote: Enumerating objects: 269, done.
# remote: Counting objects: 100% (269/269), done.
# remote: Compressing objects: 100% (162/162), done.
# remote: Total 269 (delta 118), reused 252 (delta 105), pack-reused 0 (from 0)
# Receiving objects: 100% (269/269), 14.04 MiB | 7.70 MiB/s, done.
# Resolving deltas: 100% (118/118), done.

# %% [markdown]
# After running the cell above, if you open the "Files" tab on Google Colab (the icon in the left navigation bar that looks like a folder), you will see that we now have a folder called `TreeSwift`, which contains the cloned contents of the GitHub repository.

# %% [markdown]
# # Installing Analysis Dependencies
#
# If you look through the Python scripts within the [`scripts`](https://github.com/niemasd/TreeSwift-Paper/tree/master/scripts) folder of the aforementioned GitHub repository, you'll notice that they [depend on](https://github.com/niemasd/TreeSwift-Paper/blob/ca754155014cd116ce48fdc570b5b47f9bac4cd0/scripts/figures.py#L16-L20) the following Python packages that are not part of the [Python Standard Library](https://docs.python.org/3/library/index.html) and must thus be installed: [NumPy](https://numpy.org/), [Matplotlib](https://matplotlib.org/), and [seaborn](https://seaborn.pydata.org/).
#
# These packages are simply used to visualize the results of the benchmark experiment (i.e., they are not integral to the benchmark experiment itself), so it isn't critical for us to use the exact same versions that were used in the original paper. If we *really* wanted to, we could perform the same exploration as we did with the tree packages to find the most recent version of these packages released before [July 30, 2019](https://github.com/niemasd/TreeSwift-Paper/commit/179f6b6a3c8de30dee305af8aff472c1636b1b7b), but for the sake of simplicity, we will use the most recent versions of each of these packages.
#
# We can install all of the packages needed for visualizing the results of our experiment by running the following cell, which should take around 30 seconds to finish running.

# %%
# install packages needed for visualizing our results
# !pip install -q numpy
# !pip install -q matplotlib
# !pip install -q seaborn
# Out:
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Running Our Own Benchmark

# %%
# !python TreeSwift/scripts/benchmark.py
# Out:
# === Running task: height ===
# - X = 100 leaves. dendropy.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'height']
#  treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'height']
#  ete3.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'height']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'height']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'height']
#
# - X = 1000 leaves. dendropy.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'height']
#  treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'height']
#  ete3.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'height']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'height']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'height']
#
# - X = 10000 leaves. dendropy.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'height']
#  treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'height']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'height']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'height']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'height']
#
# === Running task: average_length ===
# - X = 100 leaves. dendropy.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'average_length']
#  treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'average_length']
#  ete3.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'average_length']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'average_length']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'average_length']
#
# - X = 1000 leaves. dendropy.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'average_length']
#  treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'average_length']
#  ete3.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'average_length']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'average_length']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'average_length']
#
# - X = 10000 leaves. dendropy.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'average_length']
#  treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'average_length']
#  ete3.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'average_length']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'average_length']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'average_length']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'average_length']
#
# === Running task: distance ===
# - X = 100 leaves. dendropy.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'distance']
#  treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'distance']
#  ete3.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'distance']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'distance']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'distance']
#
# - X = 1000 leaves. dendropy.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'distance']
#  treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'distance']
#  ete3.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'distance']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'distance']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'distance']
#
# - X = 10000 leaves. treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'distance']
#  ete3.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'distance']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'distance']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'distance']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'distance']
#
# === Running task: treeness ===
# - X = 100 leaves. dendropy.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'dendropy', 'treeness']
#  treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'treeswift', 'treeness']
#  ete3.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'ete3', 'treeness']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'networkx', 'treeness']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n100.tre.gz', 'biophylo', 'treeness']
#
# - X = 1000 leaves. dendropy.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'dendropy', 'treeness']
#  treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'treeswift', 'treeness']
#  ete3.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'ete3', 'treeness']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'networkx', 'treeness']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n1000.tre.gz', 'biophylo', 'treeness']
#
# - X = 10000 leaves. dendropy.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'dendropy', 'treeness']
#  treeswift.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'treeswift', 'treeness']
#  ete3.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'ete3', 'treeness']
#  networkx.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'networkx', 'treeness']
#  biophylo.['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'treeness']
# .['python3', 'TreeSwift/scripts/time.py', 'TreeSwift/data/tree_n10000.tre.gz', 'biophylo', 'treeness']

# %% [markdown]
# Now, let's create plots from our own benchmarking results! This cell should take around 30 seconds to finish running.

# %%
# !python3 TreeSwift/scripts/figures.py data.pkl.gz

# %% [markdown]
# After running the cell above, if you open the "Files" tab on Google Colab (the icon in the left navigation bar that looks like a folder), you will see all of the PDFs produced by [`figures.py`](https://github.com/niemasd/TreeSwift-Paper/blob/master/scripts/figures.py).
#
# *Note: You may need to close and reopen the "Files" tab to get the PDFs to appear after running the cell above.*
